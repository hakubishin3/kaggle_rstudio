# %%
import feather
import copy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# %%
train = feather.read_dataframe('../data/interim/train.ftr')
test = feather.read_dataframe('../data/interim/test.ftr')

train['totals.transactionRevenue'] = train['totals.transactionRevenue'].astype(float)
train['totals.transactionRevenue_log'] = train['totals.transactionRevenue'].apply(lambda x: np.log(x) if x==x else 0)
train['date'] = pd.to_datetime(train['date'], format='%Y%m%d')
test['date'] = pd.to_datetime(test['date'], format='%Y%m%d')

train.shape, test.shape
# Out:
# ((903653, 56), (804684, 53))

# %%
traffic_columns_train = [col for col in train.columns if "trafficSource" in col]
train[traffic_columns_train].dtypes
# Out:
# trafficSource.adContent                              object
# trafficSource.adwordsClickInfo.adNetworkType         object
# trafficSource.adwordsClickInfo.criteriaParameters    object
# trafficSource.adwordsClickInfo.gclId                 object
# trafficSource.adwordsClickInfo.isVideoAd             object
# trafficSource.adwordsClickInfo.page                  object
# trafficSource.adwordsClickInfo.slot                  object
# trafficSource.campaign                               object
# trafficSource.campaignCode                           object
# trafficSource.isTrueDirect                           object
# trafficSource.keyword                                object
# trafficSource.medium                                 object
# trafficSource.referralPath                           object
# trafficSource.source                                 object
# dtype: object

# %%
traffic_columns_train
# Out:
# ['trafficSource.adContent',
#  'trafficSource.adwordsClickInfo.adNetworkType',
#  'trafficSource.adwordsClickInfo.criteriaParameters',
#  'trafficSource.adwordsClickInfo.gclId',
#  'trafficSource.adwordsClickInfo.isVideoAd',
#  'trafficSource.adwordsClickInfo.page',
#  'trafficSource.adwordsClickInfo.slot',
#  'trafficSource.campaign',
#  'trafficSource.campaignCode',
#  'trafficSource.isTrueDirect',
#  'trafficSource.keyword',
#  'trafficSource.medium',
#  'trafficSource.referralPath',
#  'trafficSource.source']

# %%
traffic_columns_test = [col for col in test.columns if "trafficSource" in col]
test[traffic_columns_test].dtypes
# Out:
# trafficSource.adContent                              object
# trafficSource.adwordsClickInfo.adNetworkType         object
# trafficSource.adwordsClickInfo.criteriaParameters    object
# trafficSource.adwordsClickInfo.gclId                 object
# trafficSource.adwordsClickInfo.isVideoAd             object
# trafficSource.adwordsClickInfo.page                  object
# trafficSource.adwordsClickInfo.slot                  object
# trafficSource.campaign                               object
# trafficSource.isTrueDirect                           object
# trafficSource.keyword                                object
# trafficSource.medium                                 object
# trafficSource.referralPath                           object
# trafficSource.source                                 object
# dtype: object

# %% [markdown]
# ### 欠損値

# %%
def find_missing(data):
    total = data.isnull().sum().sort_values(ascending = False)
    percent = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending = False)
    df = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return df.loc[~(df['Total']==0)]

miss_train = find_missing(train[traffic_columns_train])
miss_test = find_missing(test[traffic_columns_test])
display(miss_train)
display(miss_test)
# Out:
#                                                Total    Percent
# trafficSource.campaignCode                    903652  99.999889
# trafficSource.adContent                       892707  98.788694
# trafficSource.adwordsClickInfo.slot           882193  97.625195
# trafficSource.adwordsClickInfo.page           882193  97.625195
# trafficSource.adwordsClickInfo.isVideoAd      882193  97.625195
# trafficSource.adwordsClickInfo.adNetworkType  882193  97.625195
# trafficSource.adwordsClickInfo.gclId          882092  97.614018
# trafficSource.isTrueDirect                    629648  69.678073
# trafficSource.referralPath                    572712  63.377425
# trafficSource.keyword                         502929  55.655102
#                                                Total    Percent
# trafficSource.adContent                       750893  93.315264
# trafficSource.adwordsClickInfo.slot           750870  93.312406
# trafficSource.adwordsClickInfo.page           750870  93.312406
# trafficSource.adwordsClickInfo.isVideoAd      750870  93.312406
# trafficSource.adwordsClickInfo.adNetworkType  750870  93.312406
# trafficSource.adwordsClickInfo.gclId          750822  93.306441
# trafficSource.referralPath                    569361  70.755850
# trafficSource.isTrueDirect                    544171  67.625428
# trafficSource.keyword                         391032  48.594479

# %% [markdown]
# ### 各カラムの中身を簡易集計

# %%
def aggregates_train_test(colname):
    summary_train = train.groupby(colname).count()['date'].sort_values(ascending=False)
    summary_test = test.groupby(colname).count()['date'].sort_values(ascending=False)
    summary_train.name = 'train'
    summary_test.name = 'test'
    result = pd.concat([summary_train, summary_test], axis=1, sort=True, join='outer').sort_values('train', ascending=False)
    return result

# %%
for col in traffic_columns_test:
    print(col)
    display(aggregates_train_test(col))
# Out:
# trafficSource.adContent
#                                      train     test
# Google Merchandise Collection       5122.0   1640.0
# Google Online Store                 1245.0    528.0
# Display Ad created 3/11/14           967.0   1377.0
# Full auto ad IMAGE ONLY              822.0      NaN
# Ad from 12/13/16                     610.0      NaN
# Ad from 11/3/16                      489.0      NaN
# Display Ad created 3/11/15           392.0      NaN
# {KeyWord:Google Brand Items}         251.0    167.0
# {KeyWord:Google Merchandise}         155.0    119.0
# Ad from 11/7/16                      123.0      NaN
# First Full Auto Template Test Ad      87.0      NaN
# Google Merchandise                    87.0      NaN
# 20% discount                          75.0      NaN
# {KeyWord:Google Branded Gear}         67.0     28.0
# {KeyWord:Looking for Google Bags?}    65.0     24.0
# Swag with Google Logos                64.0     83.0
# Display Ad created 11/17/14           50.0      NaN
# {KeyWord:Want Google Stickers?}       42.0     22.0
# JD_5a_v1                              41.0      NaN
# {KeyWord:Google Drinkware}            32.0     23.0
# {KeyWord:Google Men's T-Shirts}       30.0      8.0
# LeEco_1a                              25.0      NaN
# {KeyWord:Google Branded Kit}          16.0      3.0
# Full auto ad TEXT ONLY                16.0      NaN
# {KeyWord:Google Branded Apparel}      10.0      NaN
# Want Google Sunglasses                 8.0      1.0
# Full auto ad TEXT/NATIVE               7.0      NaN
# Google Paraphernalia                   7.0      1.0
# {KeyWord:Google Branded Outerwear}     5.0      NaN
# Google Store                           4.0      4.0
# ...                                    ...      ...
# Ad from 12/21/16                       NaN     48.0
# BQ                                     NaN    287.0
# Bags 160 x 600                         NaN     13.0
# Bags 300x250                           NaN     90.0
# Bags 336x280                           NaN     49.0
# Drinkware 120x600                      NaN      6.0
# Drinkware 336x280                      NaN     96.0
# Google Apparel                         NaN      1.0
# Google Merchandise Store               NaN  39566.0
# Men's Apparel from Google              NaN      1.0
# Office 2018 - 120 x 600                NaN      7.0
# Office Placement 160x600               NaN     14.0
# Official Google Merchandise            NaN    866.0
# Placememnt Drinkware 160x600           NaN     48.0
# Placement 300 x 250                    NaN    159.0
# Placement 336x280                      NaN     47.0
# Placement Accessores 300 x 250         NaN   3040.0
# Placement Accessories 160 x 600        NaN    261.0
# Placement Accessories 300 x 250        NaN    280.0
# Placement Accessories 336 x 280        NaN    308.0
# Placement Accessories2 120 x 600       NaN     24.0
# Placement Drinkware 300x250            NaN    653.0
# Placement Elecronics 300 x 250         NaN    190.0
# Placement Electronics 160 x 600        NaN     25.0
# Placement Office 300x250               NaN     80.0
# Placement Office 336x280               NaN     15.0
# Smart display ad - 2/6/2018            NaN     33.0
# Smart display ad - 8/17/2017           NaN   2664.0
# cool                                   NaN      2.0
# test_tyler_hr_merchant                 NaN      8.0
#
# [76 rows x 2 columns]
# trafficSource.adwordsClickInfo.adNetworkType
#                    train   test
# Google Search    21453.0  11590
# Search partners      7.0      1
# Content              NaN  42223
# trafficSource.adwordsClickInfo.criteriaParameters
#                                                     train    test
# trafficSource.adwordsClickInfo.criteriaParameters
# not available in demo dataset                      903653  804684
# trafficSource.adwordsClickInfo.gclId
#                                                     train  test
# Cj0KEQjwmIrJBRCRmJ_x7KDo-9oBEiQAuUPKMufMpuG3Zdw...   70.0   NaN
# Cj0KEQjw1ee_BRD3hK6x993YzeoBEiQA5RH_BEA562M9tvl...   41.0   NaN
# CJH1vbf94M8CFUElgQodyakHgQ                           29.0   NaN
# Cj0KEQiAw_DEBRChnYiQ_562gsEBEiQA4LcssmB_RWgvpPn...   27.0   NaN
# CjwKEAiAj7TCBRCp2Z22ue-zrj4SJACG7SBEJui6ggr6ocA...   24.0   NaN
# CN_u9PaVhdACFcNahgodTCQAjw                           22.0   NaN
# CjwKEAiAxKrFBRDm25f60OegtwwSJABgEC-Z0_DLPcXHm1Z...   21.0   NaN
# CNHp7Nf2ytMCFVlWDQod_IoL5A                           20.0   4.0
# CjwKEAiAvs7CBRC24rao6bGCoiASJABaCt5DtalFxcoSsvr...   20.0   NaN
# CjwKEAjw387JBRDPtJePvOej8kASJADkV9TLLYm88mDQieF...   18.0   NaN
# CJ6xtee6j9ACFQqDfgod8TkDNw                           18.0   NaN
# Cj0KEQiAtqHEBRCNrdC6rYq9_oYBEiQAejvRlydKqhjz1oz...   17.0   NaN
# Cj0KEQiA6_TBBRDInaPjhcelt5oBEiQApPeTFwpkek9qjhp...   14.0   NaN
# Cj0KEQiAuonGBRCaotXoycysvIMBEiQAcxV0nH04PTH5N1j...   14.0   NaN
# Cj0KEQjwuZvIBRD-8Z6B2M2Sy68BEiQAtjYS3LI8d1dPIlf...   14.0   NaN
# Cj0KEQjwo-XIBRCOycL7hsuI_NoBEiQAuS6HtHOpolLDj1N...   14.0   NaN
# CLHAuey57M0CFcUmhgod5KoAtg                           13.0   NaN
# Cj0KEQiA5IHEBRCLr_PZvq2_6qcBEiQAL4cQ011rzjEGMvY...   13.0   NaN
# CjwKEAjwzN27BRDFn9aAwLmH2yISJABWuEXch7u7TBTE6Pp...   13.0   NaN
# Cj0KCQjwktHLBRDsARIsAFBSb6x3yDhaJwwJNzgCb4oakNp...   12.0   3.0
# CjwKEAjw5_vHBRCBtt2NqqCDjiESJABD5rCJ5tpiaut2Yg5...   12.0   NaN
# CJqomdrD6c8CFQkPaQodftgGhg                           11.0   NaN
# Cj0KEQiAot_FBRCqt8jVsoDKoZABEiQAqFL76LHSlBk--Ne...   11.0   NaN
# Cj0KEQjw57W9BRDM9_a-2vWJ68EBEiQAwPNFKyoNXka0H6q...   11.0   NaN
# CjwKEAiAg5_CBRDo4o6e4o3NtG0SJAB-IatYXBAYgFg8NK3...   10.0   NaN
# CKvj8PjynNACFQ-DaQodGm4N-Q                           10.0   NaN
# CjwKEAjwtJzLBRC7z43vr63nr3wSJABjJDgJS6U-a8yZzN8...   10.0   2.0
# CjwKEAiA6rrBBRDsrLGM4uTPkWASJADnWZQ48mvLDyfiCly...   10.0   NaN
# Cj0KEQiA0L_FBRDMmaCTw5nxm-ABEiQABn-VqYPBjHllWA_...   10.0   NaN
# Cj0KEQjw7pHLBRDqs-X8hZ3Mgp0BEiQAXIo9rsfCcE32Gb8...    9.0   NaN
# ...                                                   ...   ...
# EAIaIQobChMIzrn18OWU2AIVTFcNCh0S7QtxEAAYAiAAEgK...    NaN   1.0
# EAIaIQobChMIzrrKm-n81QIVhq1pCh2yjwL5EAEYASAAEgK...    NaN   1.0
# EAIaIQobChMIzruS2s_G2QIVjLXACh3LKgWmEAAYASAAEgJ...    NaN   1.0
# EAIaIQobChMIzsWr-bXD2AIVjIztCh0I1ACqEAEYASAAEgL...    NaN   1.0
# EAIaIQobChMIzsaW4umq2AIVgqjICh15iQY2EAEYASAAEgJ...    NaN   1.0
# EAIaIQobChMIztDVm7-b2AIVisjjBx1HWwH4EAEYASAAEgI...    NaN   1.0
# EAIaIQobChMIztHrvMeb2AIVSGoBCh0uTgYnEAEYASAAEgI...    NaN   1.0
# EAIaIQobChMIztbp5r6o2AIVEwxlCh0TMgOnEAEYASAAEgJ...    NaN   1.0
# EAIaIQobChMIzted1I-b2AIVVGrBCh1SUwUrEAEYASAAEgJ...    NaN   1.0
# EAIaIQobChMIztr2o4_x1gIV2LjACh0VCAINEAAYASAAEgJ...    NaN   1.0
# EAIaIQobChMIztufyaqk2AIVSIV-Ch2aTgCAEAAYAiAAEgI...    NaN   1.0
# EAIaIQobChMIzu6gxqy_1wIVF0sNCh3p9Q3JEAAYASAAEgK...    NaN   1.0
# EAIaIQobChMIzuH735uV1wIVRZV-Ch3kfA0iEAAYAiAAEgK...    NaN   1.0
# EAIaIQobChMIzu_17M681wIVTN5kCh3EeAbYEAEYASAAEgI...    NaN   1.0
# EAIaIQobChMIzubBoL711gIVlYRpCh3gjA61EAAYASAAEgJ...    NaN   1.0
# EAIaIQobChMIzuflyZvU2AIVD57ICh3sLQeZEAEYASAAEgL...    NaN   1.0
# EAIaIQobChMIzui-046d2AIVQ-BkCh2lRAEBEAEYASAAEgJ...    NaN   1.0
# EAIaIQobChMIzuih7rGh2AIVBBgBCh0pqgaCEAEYASAAEgJ...    NaN   1.0
# EAIaIQobChMIzv37g7u21wIVBohRCh1uegqhEAEYASAAEgI...    NaN   1.0
# EAIaIQobChMIzv76qaCZ2AIVypJkCh3HRwJFEAEYASAAEgI...    NaN   1.0
# EAIaIQobChMIzvHPyKmF1wIVRh6GCh2-0QG1EAAYASAAEgK...    NaN   1.0
# EAIaIQobChMIzvLv1oWu2AIVRLnACh0l1QIwEAAYASAAEgK...    NaN   1.0
# EAIaIQobChMIzvOn497a2AIVDzxPCh2scQfpEAEYASAAEgI...    NaN   1.0
# EAIaIQobChMIzvTHv9ij2AIVSjFpCh1SVwASEAEYASAAEgL...    NaN   1.0
# EAIaIQobChMIzvbVzu-u1wIVBmvBCh1lTwhqEAEYASAAEgI...    NaN   1.0
# EAIaIQobChMIzve4sMXN2AIVkEA3Ch2aUwJfEAEYASAAEgJ...    NaN   2.0
# EAIaIQobChMIzvjU-fGj1wIVCjFpCh2HmQbyEAAYASAAEgJ...    NaN   1.0
# EAIaIQobChMIzvrG24Wn2AIVExQbCh06bgklEAAYASAAEgK...    NaN   1.0
# EAIaIQobChMIzvr_iIa92AIVA2zBCh3KRQT7EAEYASAAEgL...    NaN   1.0
# EAIaIQobChMIzvvD98-_1wIVh6CHCh2FKA9YEAEYASAAEgI...    NaN   1.0
#
# [59008 rows x 2 columns]
# trafficSource.adwordsClickInfo.isVideoAd
#                                           train   test
# trafficSource.adwordsClickInfo.isVideoAd
# False                                     21460  53814
# trafficSource.adwordsClickInfo.page
#       train     test
# 1   21362.0  52551.0
# 2      73.0    984.0
# 3      10.0    162.0
# 5       7.0     23.0
# 7       3.0      3.0
# 4       2.0     78.0
# 9       2.0      1.0
# 14      1.0      NaN
# 12      NaN      1.0
# 6       NaN     10.0
# 8       NaN      1.0
# trafficSource.adwordsClickInfo.slot
#                           train   test
# Top                     20956.0  11491
# RHS                       504.0  42246
# Google Display Network      NaN     77
# trafficSource.campaign
#                                                        train      test
# (not set)                                           865347.0  728927.0
# Data Share Promo                                     16403.0   16511.0
# AW - Dynamic Search Ads Whole Site                   14244.0    8933.0
# AW - Accessories                                      7070.0    2645.0
# test-liyuhz                                            392.0       NaN
# AW - Electronics                                        96.0       1.0
# Retail (DO NOT EDIT owners nophakun and tianyu)         50.0       NaN
# AW - Apparel                                            46.0      12.0
# All Products                                             4.0       NaN
# Data Share                                               1.0       NaN
# "google + redesign/Accessories March 17" 1 Day           NaN       5.0
# "google + redesign/Accessories March 17" All Users       NaN     562.0
# "google + redesign/Accessories March 17" All Us...       NaN    1179.0
# (direct)                                                 NaN      12.0
# 1000557 | GA | US | en | Hybrid | GDN Remarketing        NaN   15149.0
# 1000557 | GA | US | en | Hybrid | GDN Text+Bann...       NaN   24410.0
# Gmail type campaign                                      NaN       2.0
# Lifestyles & Hobbies/Shutterbugs                         NaN     131.0
# Media & Entertainment/Movie Lovers                       NaN     311.0
# Media & Entertainment/Music Lovers                       NaN     195.0
# Page: contains "/google+redesign/bags" 1 Day             NaN      27.0
# Page: contains "/google+redesign/bags" All Users         NaN      83.0
# Page: contains "/google+redesign/bags" All User...       NaN      42.0
# Page: contains "/google+redesign/drinkware"              NaN     192.0
# Page: contains "/google+redesign/drinkware" Sim...       NaN     611.0
# Page: contains "/google+redesign/electronics"            NaN      97.0
# Page: contains "/google+redesign/electronics" S...       NaN       9.0
# Page: contains "/google+redesign/office"                 NaN      93.0
# Page: contains "/google+redesign/office" Simila...       NaN     182.0
# Run of Network Line Item                                 NaN     428.0
# Smart Display Campaign                                   NaN    2664.0
# Sports & Fitness/Health & Fitness Buffs                  NaN     463.0
# Technology/Mobile Enthusiasts                            NaN     310.0
# Technology/Technophiles                                  NaN     290.0
# Value Shoppers Affinity                                  NaN     208.0
# trafficSource.isTrueDirect
#                              train    test
# trafficSource.isTrueDirect
# True                        274005  260513
# trafficSource.keyword
#                                                        train      test
# (not provided)                                      366363.0  346391.0
# 6qEhsCssdK0z36ri                                     11503.0    6221.0
# (Remarketing/Content targeting)                       2298.0    4940.0
# 1hZbAqLCbjwfgOH7                                      2264.0    1732.0
# google merchandise store                              2209.0     778.0
# Google Merchandise                                    1648.0     480.0
# google store                                          1277.0     303.0
# youtube                                                568.0     202.0
# (User vertical targeting)                              489.0   25761.0
# 1X4Me6ZKNV0zg-jV                                       467.0     980.0
# (automatic matching)                                   427.0   18354.0
# +google +store                                         377.0     170.0
# +Google +Merchandise                                   352.0     196.0
# (content targeting)                                    299.0       2.0
# +google +merchandise +store                            258.0     125.0
# YouTube Merchandise                                    254.0       9.0
# youtube merch                                          247.0      30.0
# google merchandise                                     238.0      86.0
# google merch                                           210.0     103.0
# Youtube                                                166.0      50.0
# +Google +Products                                      148.0     106.0
# https://www.googlemerchandisestore.com/                135.0     167.0
# google shop                                            135.0      39.0
# Arts & Entertainment                                   126.0       NaN
# google online store                                    111.0      16.0
# youtube t shirt                                        107.0      64.0
# +youtube +merch                                        102.0       NaN
# +YouTube +Merchandise                                  102.0       NaN
# google t shirt                                         101.0      49.0
# +google +stores                                         99.0     224.0
# ...                                                      ...       ...
# жбоь7 цом                                                NaN       1.0
# пщщпду                                                   NaN       2.0
# рюкзак google                                            NaN       1.0
# рюкзак гугл                                              NaN       1.0
# рюкзак от google                                         NaN       1.0
# ютуб шоп                                                 NaN       1.0
# ютцуб                                                    NaN       1.0
# חנות גוגל                                                NaN       1.0
# فوتبول                                                   NaN       1.0
# قوقل                                                     NaN       1.0
# يوتوب م                                                  NaN       1.0
# يوتيوب ستور                                              NaN       1.0
# गूगल हट वीडीवपाकीसतानी                                   NaN       1.0
# बैग googly                                               NaN       1.0
# युटू स्टोर                                               NaN       1.0
# युतुब आनलाइन                                             NaN       1.0
# यू tube                                                  NaN       1.0
# यू टी ऊबे                                                NaN       1.0
# यूट्यूब stor                                             NaN       1.0
# यूट्यूब स्टोर                                            NaN       1.0
# यूट्यूब.कॉम                                              NaN       1.0
# यूट्यूबt                                                 NaN       1.0
# यौ ट्यूब                                                 NaN       2.0
# रेड टुब                                                  NaN       1.0
# रेड तुबे                                                 NaN       1.0
# ঢাকা বিশ্ববিদ্যালয়ের আশেপাশে কোথাও কি t shirt ত...       NaN       1.0
# নতুন T-shirt                                             NaN       1.0
# กูเกิ้ง ยูทุป                                            NaN       1.0
# ストア グーグル                                                 NaN       1.0
# 구글 usa                                                   NaN       1.0
#
# [5392 rows x 2 columns]
# trafficSource.medium
#                        train    test
# trafficSource.medium
# organic               381561  357402
# referral              330955  235323
# (none)                143026  130108
# cpc                    25326   62524
# affiliate              16403   16512
# cpm                     6262    2798
# (not set)                120      17
# trafficSource.referralPath
#                                                       train     test
# /                                                   75523.0  62770.0
# /yt/about/                                          71036.0   8127.0
# /analytics/web/                                     14620.0  18492.0
# /yt/about/tr/                                       14599.0      1.0
# /yt/about/vi/                                       13753.0      NaN
# /yt/about/es-419/                                   12735.0      1.0
# /yt/about/pt-BR/                                    12003.0      2.0
# /yt/about/th/                                       11430.0      NaN
# /yt/about/ru/                                       11193.0      1.0
# /yt/about/es/                                        7092.0      3.0
# /yt/about/en-GB/                                     6576.0      6.0
# /yt/about/fr/                                        5704.0      1.0
# /yt/about/ja/                                        4679.0      1.0
# /permissions/using-the-logo.html                     4365.0   3545.0
# /yt/about/ar/                                        4280.0     15.0
# /yt/about/pl/                                        3617.0      NaN
# /yt/about/de/                                        2860.0      3.0
# /yt/about/zh-TW/                                     2799.0      1.0
# /yt/about/ro/                                        2139.0      NaN
# /od/Things-To-Do-in-Silicon-Valley/fl/How-To-Vi...   2056.0      NaN
# /yt/about/ko/                                        2036.0      NaN
# /yt/about/it/                                        2012.0      NaN
# /yt/about/id/                                        1888.0      NaN
# /YKEI_mrn/items/c10b14f9a69ff71b1b7a                 1784.0   1574.0
# /analytics/web/inpage_launch                         1638.0      NaN
# /a/google.com/googletopia/discounts-deals-and-f...   1118.0   4898.0
# /offer/2145                                          1064.0   7235.0
# /yt/about/iw/                                        1053.0      3.0
# /mail/u/0/                                           1034.0    838.0
# /yt/about/zh-CN/                                      926.0      NaN
# ...                                                     ...      ...
# /yt/space/newyork/calendar.html                         NaN     10.0
# /yt/space/newyork/facilities.html                       NaN     19.0
# /yt/space/newyork/learn.html                            NaN      1.0
# /yt/space/newyork/location.html                         NaN      1.0
# /yt/space/newyork/sets.html                             NaN      1.0
# /yt/space/newyork/unlock.html                           NaN      4.0
# /yt/space/paris/                                        NaN      5.0
# /yt/space/paris/calendar.html                           NaN      3.0
# /yt/space/rio/                                          NaN      3.0
# /yt/space/rio/access.html                               NaN      1.0
# /yt/space/rio/unlock.html                               NaN      1.0
# /yt/space/rio/workshops-events.html                     NaN      2.0
# /yt/space/tokyo/                                        NaN      8.0
# /yt/space/tokyo/calendar.html                           NaN      6.0
# /yt/space/tokyo/creative.html                           NaN      1.0
# /yt/space/tokyo/facilities.html                         NaN      3.0
# /yt/space/tokyo/learn.html                              NaN      1.0
# /yt/space/tokyo/location.html                           NaN      1.0
# /yt/space/tokyo/unlock.html                             NaN      4.0
# /yt/space/toronto/                                      NaN     12.0
# /yt/space/toronto/access.html                           NaN      7.0
# /yt/space/toronto/calendar.html                         NaN      4.0
# /yt/space/toronto/index.html                            NaN      1.0
# /yt/space/toronto/learn.html                            NaN      1.0
# /yt/space/toronto/unlock.html                           NaN      1.0
# /yt/startcreating/ALL_de/index.html                     NaN      1.0
# /yt/startcreating/ALL_jp/index.html                     NaN     16.0
# /yt/videomasthead/                                      NaN     27.0
# /yt/videomasthead/tr/index.html                         NaN      1.0
# /yt/videomasthead/zh-HK/index.html                      NaN      1.0
#
# [3196 rows x 2 columns]
# trafficSource.source
#                                      train      test
# google                            400788.0  417104.0
# youtube.com                       212602.0  116848.0
# (direct)                          143028.0  130124.0
# mall.googleplex.com                66416.0   54125.0
# Partners                           16411.0   16520.0
# analytics.google.com               16172.0   21264.0
# dfa                                 5686.0    1018.0
# google.com                          4669.0    3672.0
# m.facebook.com                      3365.0    3372.0
# baidu                               3356.0    1615.0
# sites.google.com                    2983.0    6089.0
# facebook.com                        2296.0    1288.0
# siliconvalley.about.com             2097.0       NaN
# reddit.com                          2022.0    2070.0
# qiita.com                           1813.0    1581.0
# quora.com                           1546.0    1486.0
# bing                                1530.0    1838.0
# t.co                                1529.0     476.0
# yahoo                               1480.0     956.0
# mail.google.com                     1457.0    1101.0
# gdeals.googleplex.com               1063.0    7235.0
# groups.google.com                   1025.0     984.0
# l.facebook.com                       795.0     734.0
# blog.golang.org                      742.0     640.0
# dealspotr.com                        528.0     222.0
# plus.google.com                      524.0     126.0
# moma.corp.google.com                 419.0    1088.0
# docs.google.com                      388.0     190.0
# productforums.google.com             364.0     308.0
# google.co.jp                         356.0     285.0
# ...                                    ...       ...
# mail1.swic.edu                         NaN       1.0
# memegen.googleplex.com                 NaN      49.0
# my.uclaextension.edu                   NaN       3.0
# my.yahoo.com                           NaN       8.0
# myasucourses.asu.edu                   NaN      11.0
# mycrabnet.googleplex.com               NaN       1.0
# nashda.mtv.corp.google.com:18080       NaN       1.0
# nashda.mtv.corp.google.com:8080        NaN       1.0
# nl.pinterest.com                       NaN       1.0
# notifications.google.com               NaN       7.0
# p.qiao.baidu.com                       NaN       1.0
# papyrus.mtv.corp.google.com:9011       NaN       1.0
# partnerads.ysm.yahoo.com               NaN       1.0
# play.google.com                        NaN       1.0
# psahu2.nyc.corp.google.com:7000        NaN       1.0
# qc.search.yahoo.com                    NaN       1.0
# r.search.aol.com                       NaN      12.0
# redwood.corp.google.com                NaN       1.0
# results.searchlock.com                 NaN      19.0
# ru.pinterest.com                       NaN       1.0
# sans.irv.corp.google.com:9001          NaN       2.0
# search.mywebsearch.com                 NaN       1.0
# secq-ng.googleplex.com                 NaN       5.0
# smile.amazon.com                       NaN       1.0
# thompj.mtv.corp.google.com:7000        NaN       1.0
# trends.google.com                      NaN       1.0
# uwec.courses.wisconsin.edu             NaN       1.0
# ve.search.yahoo.com                    NaN       2.0
# wikihow.com                            NaN       3.0
# youtube.thinkwithgoogle.com            NaN      19.0
#
# [500 rows x 2 columns]

# %% [markdown]
# ### trafficSource.adContentについて

# %% [markdown]
# - トラフィック参照元の広告内容。utm_content URL パラメータで設定できます。

# %%
train['trafficSource.adContent'].nunique(), test['trafficSource.adContent'].nunique()
# Out:
# (44, 51)

# %% [markdown]
# - train, testそれぞれの期間のみに登場する広告が多い。

# %%
train[train['trafficSource.adContent']=="Full auto ad IMAGE ONLY"].date.max()
# Out:
# 20170728

# %%
test[test['trafficSource.adContent']=="Full auto ad IMAGE ONLY"].date.max()
# Out:
# nan

# %% [markdown]
# #### kernelの名寄せを試してみる。

# %%
def adcontents_mapping(x):
    if  ('google' in x):
        return 'google'
    elif '(not set)' in x or 'nan' in x:
        return x
    elif 'ad' in x:
        return 'ad'
    else:
        return 'others'

# %%
train['adContent_map'] = train['trafficSource.adContent'].map(lambda x:adcontents_mapping(str(x).lower())).astype('str')
test['adContent_map'] = test['trafficSource.adContent'].map(lambda x:adcontents_mapping(str(x).lower())).astype('str')

# %%
display(aggregates_train_test("adContent_map"))
# Out:
#                 train    test
# adContent_map
# others         892858  756614
# google           7223   43095
# ad               3572    4975

# %%
train['adContent_map'].isnull().sum(), train['trafficSource.adContent'].isnull().sum()
# Out:
# (0, 892707)

# %% [markdown]
# ### trafficSource.adwordsClickInfo.adNetworkTypeについて

# %% [markdown]
# - ネットワークの種類。値は、次のいずれかになります。{“Google Search", "Content", "Search partners", "Ad Exchange", "Yahoo Japan Search", "Yahoo Japan AFS", “unknown”}

# %%
train['trafficSource.adwordsClickInfo.adNetworkType'].unique(), test['trafficSource.adwordsClickInfo.adNetworkType'].unique()
# Out:
# (array([None, 'Google Search', 'Search partners'], dtype=object),
#  array([None, 'Google Search', 'Content', 'Search partners'], dtype=object))

# %%
def adnetworktype_mapping(x):
    if  ('google search' in x):
        return 'google search'
    else:
        return 'others'

# %%
train['adnetworktype_map'] = train['trafficSource.adwordsClickInfo.adNetworkType'].map(lambda x:adnetworktype_mapping(str(x).lower())).astype('str')
test['adnetworktype_map'] = test['trafficSource.adwordsClickInfo.adNetworkType'].map(lambda x:adnetworktype_mapping(str(x).lower())).astype('str')

# %%
display(aggregates_train_test("adnetworktype_map"))
# Out:
#                     train    test
# adnetworktype_map
# others             882200  793094
# google search       21453   11590

# %%
train['adnetworktype_map'].isnull().sum(), train['trafficSource.adwordsClickInfo.adNetworkType'].isnull().sum()
# Out:
# (0, 882193)

# %% [markdown]
# ### trafficSource.adwordsClickInfo.gclIdについて

# %% [markdown]
# - Google クリック ID。
# https://www.ja.advertisercommunity.com/t5/%E3%81%9D%E3%81%AE%E4%BB%96-Google-AdWords/gclid-%E4%BB%A5%E9%99%8D%E3%81%AE%E3%83%91%E3%83%A9%E3%83%A1%E3%83%BC%E3%82%BFurl%E3%81%AB%E9%96%A2%E3%81%99%E3%82%8B%E8%B3%AA%E5%95%8F/m-p/8814/highlight/true

# %%
train['trafficSource.adwordsClickInfo.gclId'].nunique(), test['trafficSource.adwordsClickInfo.gclId'].nunique()
# Out:
# (17774, 41317)

# %% [markdown]
# #### それぞれ(train, test)の期間にしか出現しないものが多い。

# %% [markdown]
# 名寄せを結構頑張らないといけない

# %%
agg = aggregates_train_test("trafficSource.adwordsClickInfo.gclId")

# %%
len(agg), agg["train"].isnull().sum(), agg["test"].isnull().sum()
# Out:
# (59008, 41234, 17691)

# %%
agg[agg["train"].isnull() & agg["test"].notnull()].shape
# Out:
# (41234, 2)

# %%
agg[agg["train"].notnull() & agg["test"].isnull()].shape
# Out:
# (17691, 2)

# %% [markdown]
# ### trafficSource.adwordsClickInfo.isVideoAdについて

# %% [markdown]
# - TrueView 動画広告の場合、「true」に設定されます。

# %%
train['trafficSource.adwordsClickInfo.isVideoAd'].unique(), test['trafficSource.adwordsClickInfo.isVideoAd'].unique()
# Out:
# (array([None, False], dtype=object), array([None, False], dtype=object))

# %% [markdown]
# ### trafficSource.adwordsClickInfo.pageについて

# %% [markdown]
# - 広告が表示された検索結果のページ番号。

# %%
train['trafficSource.adwordsClickInfo.page'].nunique(), test['trafficSource.adwordsClickInfo.page'].nunique()
# Out:
# (8, 10)

# %%
aggregates_train_test("trafficSource.adwordsClickInfo.page")
# Out:
#       train     test
# 1   21362.0  52551.0
# 2      73.0    984.0
# 3      10.0    162.0
# 5       7.0     23.0
# 7       3.0      3.0
# 4       2.0     78.0
# 9       2.0      1.0
# 14      1.0      NaN
# 12      NaN      1.0
# 6       NaN     10.0
# 8       NaN      1.0

# %% [markdown]
# ### trafficSource.adwordsClickInfo.slotについて

# %% [markdown]
# - 広告の位置。値は次のいずれかになります。{“RHS", "Top"}

# %%
train['trafficSource.adwordsClickInfo.slot'].unique(), test['trafficSource.adwordsClickInfo.slot'].unique()
# Out:
# (array([None, 'Top', 'RHS'], dtype=object),
#  array([None, 'Top', 'RHS', 'Google Display Network'], dtype=object))

# %%
aggregates_train_test("trafficSource.adwordsClickInfo.slot")
# Out:
#                           train   test
# Top                     20956.0  11491
# RHS                       504.0  42246
# Google Display Network      NaN     77

# %%
def slot_mapping(x):
    if  ('top' in x):
        return 'top'
    elif  ('rhs' in x):
        return 'rhs'
    else:
        return 'others'

# %%
train['slot_map'] = train['trafficSource.adwordsClickInfo.slot'].map(lambda x:slot_mapping(str(x).lower())).astype('str')
test['slot_map'] = test['trafficSource.adwordsClickInfo.slot'].map(lambda x:slot_mapping(str(x).lower())).astype('str')

# %%
aggregates_train_test("slot_map")
# Out:
#          train    test
# others  882193  750947
# top      20956   11491
# rhs        504   42246

# %% [markdown]
# ### trafficSource.campaignについて

# %% [markdown]
# - キャンペーンの値。通常は utm_campaign URL パラメータで設定されます。
# http://rubymarketing.jp/blog/url_parameter

# %%
train['trafficSource.campaign'].nunique(), test['trafficSource.campaign'].nunique()
# Out:
# (10, 31)

# %%
display(aggregates_train_test("trafficSource.campaign"))
# Out:
#                                                        train      test
# (not set)                                           865347.0  728927.0
# Data Share Promo                                     16403.0   16511.0
# AW - Dynamic Search Ads Whole Site                   14244.0    8933.0
# AW - Accessories                                      7070.0    2645.0
# test-liyuhz                                            392.0       NaN
# AW - Electronics                                        96.0       1.0
# Retail (DO NOT EDIT owners nophakun and tianyu)         50.0       NaN
# AW - Apparel                                            46.0      12.0
# All Products                                             4.0       NaN
# Data Share                                               1.0       NaN
# "google + redesign/Accessories March 17" 1 Day           NaN       5.0
# "google + redesign/Accessories March 17" All Users       NaN     562.0
# "google + redesign/Accessories March 17" All Us...       NaN    1179.0
# (direct)                                                 NaN      12.0
# 1000557 | GA | US | en | Hybrid | GDN Remarketing        NaN   15149.0
# 1000557 | GA | US | en | Hybrid | GDN Text+Bann...       NaN   24410.0
# Gmail type campaign                                      NaN       2.0
# Lifestyles & Hobbies/Shutterbugs                         NaN     131.0
# Media & Entertainment/Movie Lovers                       NaN     311.0
# Media & Entertainment/Music Lovers                       NaN     195.0
# Page: contains "/google+redesign/bags" 1 Day             NaN      27.0
# Page: contains "/google+redesign/bags" All Users         NaN      83.0
# Page: contains "/google+redesign/bags" All User...       NaN      42.0
# Page: contains "/google+redesign/drinkware"              NaN     192.0
# Page: contains "/google+redesign/drinkware" Sim...       NaN     611.0
# Page: contains "/google+redesign/electronics"            NaN      97.0
# Page: contains "/google+redesign/electronics" S...       NaN       9.0
# Page: contains "/google+redesign/office"                 NaN      93.0
# Page: contains "/google+redesign/office" Simila...       NaN     182.0
# Run of Network Line Item                                 NaN     428.0
# Smart Display Campaign                                   NaN    2664.0
# Sports & Fitness/Health & Fitness Buffs                  NaN     463.0
# Technology/Mobile Enthusiasts                            NaN     310.0
# Technology/Technophiles                                  NaN     290.0
# Value Shoppers Affinity                                  NaN     208.0

# %% [markdown]
# #### 時間に関係する特徴。それぞれにしかないものが怖いので名寄せ

# %%
def campaign_mapping(x):
    campaign = ['(not set)', 'data share promo', 'aw - dynamic search ads whole site',
                'aw - accessories']
    if x in campaign:
        return x
    else:
        return 'others'

# %%
train['campaign_map'] = train['trafficSource.campaign'].map(lambda x:campaign_mapping(str(x).lower())).astype('str')
test['campaign_map'] = test['trafficSource.campaign'].map(lambda x:campaign_mapping(str(x).lower())).astype('str')

# %%
display(aggregates_train_test("campaign_map"))
# Out:
#                                      train    test
# (not set)                           865347  728927
# data share promo                     16403   16511
# aw - dynamic search ads whole site   14244    8933
# aw - accessories                      7070    2645
# others                                 589   47668

# %%
revenue = train[train["campaign_map"]=="others"].groupby("trafficSource.campaign")["totals.transactionRevenue"].median()
size = train[train["campaign_map"]=="others"].groupby("trafficSource.campaign").size()
pd.concat([revenue, size], axis=1).sort_values(0, ascending=False)
# Out:
#                                                  totals.transactionRevenue  \
# trafficSource.campaign
# test-liyuhz                                                     42000000.0
# AW - Electronics                                                       NaN
# Retail (DO NOT EDIT owners nophakun and tianyu)                 22950000.0
# AW - Apparel                                                    77820000.0
# All Products                                                           NaN
# Data Share                                                             NaN
#
#                                                    0
# trafficSource.campaign
# test-liyuhz                                      392
# AW - Electronics                                  96
# Retail (DO NOT EDIT owners nophakun and tianyu)   50
# AW - Apparel                                      46
# All Products                                       4
# Data Share                                         1

# %% [markdown]
# ### trafficSource.isTrueDirectについて

# %% [markdown]
# - セッションの参照元がノーリファラーの場合（ユーザーがブラウザに URL を直接入力したか、ブックマークを利用してウェブサイトにアクセスした場合）、この値は「true」に設定されます。また、連続していても互いに独立する 2 つのセッションにまったく同じキャンペーンの詳細がある場合も、「true」に設定されます。そうでない場合は「null」に設定されます。

# %%
train['trafficSource.isTrueDirect'].unique(), test['trafficSource.isTrueDirect'].unique()
# Out:
# (array([None, True], dtype=object), array([True, None], dtype=object))

# %%
train["slot"] = train["trafficSource.adwordsClickInfo.slot"].astype(str)
train.groupby(["slot"]).size()
# Out:
# slot
# None    882193
# RHS        504
# Top      20956
# dtype: int64

# %% [markdown]
# ### trafficSource.keywordについて

# %% [markdown]
# - 参照元のキーワード。通常は trafficSource.medium が「organic」または「cpc」の場合に設定されます。utm_term URL パラメータで設定できます。

# %%
train['trafficSource.keyword'].nunique(), test['trafficSource.keyword'].nunique()
# Out:
# (3659, 2415)

# %%
train['trafficSource.keyword'].astype(str).isnull().sum()
# Out:
# 0

# %% [markdown]
# ### trafficSource.mediumについて

# %% [markdown]
# - トラフィック参照元のメディア。「organic」、「cpc」、「referral」、または utm_medium URL パラメータの値となります。

# %%
train['trafficSource.medium'].unique(), test['trafficSource.medium'].unique()
# Out:
# (array(['organic', 'referral', 'cpc', 'affiliate', '(none)', 'cpm',
#         '(not set)'], dtype=object),
#  array(['organic', 'cpc', 'cpm', '(none)', 'referral', 'affiliate',
#         '(not set)'], dtype=object))

# %%
train['trafficSource.medium'].nunique(), test['trafficSource.medium'].nunique()
# Out:
# (7, 7)

# %% [markdown]
# ### trafficSource.referralPathについて

# %% [markdown]
# - trafficSource.medium が「referral」の場合、この値は参照経路に設定されます（参照のホスト名は trafficSource.source に示されます）。

# %%
train['trafficSource.referralPath'].nunique(), test['trafficSource.referralPath'].nunique()
# Out:
# (1475, 2197)

# %% [markdown]
# ### trafficSource.sourceについて

# %% [markdown]
# - トラフィックの参照元。検索エンジンの名前、参照ホスト名、または utm_source URL パラメータの値となります。

# %%
train['trafficSource.source'].nunique(), test['trafficSource.source'].nunique()
# Out:
# (380, 324)

# %% [markdown]
# #### kernelの名寄せを試してみる

# %%
def source_mapping(x):
    if  ('google' in x):
        return 'google'
    elif  ('youtube' in x):
        return 'youtube'
    elif '(not set)' in x or 'nan' in x:
        return x
    elif 'yahoo' in x:
        return 'yahoo'
    elif 'facebook' in x:
        return 'facebook'
    elif 'reddit' in x:
        return 'reddit'
    elif 'bing' in x:
        return 'bing'
    elif 'quora' in x:
        return 'quora'
    elif 'outlook' in x:
        return 'outlook'
    elif 'linkedin' in x:
        return 'linkedin'
    elif 'pinterest' in x:
        return 'pinterest'
    elif 'ask' in x:
        return 'ask'
    elif 'siliconvalley' in x:
        return 'siliconvalley'
    elif 'lunametrics' in x:
        return 'lunametrics'
    elif 'amazon' in x:
        return 'amazon'
    elif 'mysearch' in x:
        return 'mysearch'
    elif 'qiita' in x:
        return 'qiita'
    elif 'messenger' in x:
        return 'messenger'
    elif 'twitter' in x:
        return 'twitter'
    elif 't.co' in x:
        return 't.co'
    elif 'vk.com' in x:
        return 'vk.com'
    elif 'search' in x:
        return 'search'
    elif 'edu' in x:
        return 'edu'
    elif 'mail' in x:
        return 'mail'
    elif 'ad' in x:
        return 'ad'
    elif 'golang' in x:
        return 'golang'
    elif 'direct' in x:
        return 'direct'
    elif 'dealspotr' in x:
        return 'dealspotr'
    elif 'sashihara' in x:
        return 'sashihara'
    elif 'phandroid' in x:
        return 'phandroid'
    elif 'baidu' in x:
        return 'baidu'
    elif 'mdn' in x:
        return 'mdn'
    elif 'duckduckgo' in x:
        return 'duckduckgo'
    elif 'seroundtable' in x:
        return 'seroundtable'
    elif 'metrics' in x:
        return 'metrics'
    elif 'sogou' in x:
        return 'sogou'
    elif 'businessinsider' in x:
        return 'businessinsider'
    elif 'github' in x:
        return 'github'
    elif 'gophergala' in x:
        return 'gophergala'
    elif 'yandex' in x:
        return 'yandex'
    elif 'msn' in x:
        return 'msn'
    elif 'dfa' in x:
        return 'dfa'
    elif '(not set)' in x:
        return '(not set)'
    elif 'feedly' in x:
        return 'feedly'
    elif 'arstechnica' in x:
        return 'arstechnica'
    elif 'squishable' in x:
        return 'squishable'
    elif 'flipboard' in x:
        return 'flipboard'
    elif 't-online.de' in x:
        return 't-online.de'
    elif 'sm.cn' in x:
        return 'sm.cn'
    elif 'wow' in x:
        return 'wow'
    elif 'baidu' in x:
        return 'baidu'
    elif 'partners' in x:
        return 'partners'
    else:
        return 'others'

# %%
train['source_map'] = train['trafficSource.source'].map(lambda x:source_mapping(str(x).lower())).astype('str')
test['source_map'] = test['trafficSource.source'].map(lambda x:source_mapping(str(x).lower())).astype('str')

# %%
display(aggregates_train_test("source_map"))
# Out:
#                     train      test
# google             499205  520977.0
# youtube            212697  116875.0
# direct             143028  130124.0
# partners            16411   16520.0
# facebook             6523    5523.0
# dfa                  5686    1018.0
# baidu                3503    1689.0
# reddit               2106    2081.0
# siliconvalley        2097       NaN
# qiita                1818    1581.0
# yahoo                1696    1203.0
# t.co                 1550     482.0
# quora                1546    1486.0
# bing                 1536    1842.0
# golang                742     640.0
# dealspotr             528     222.0
# ask                   406     285.0
# sashihara             277     147.0
# phandroid             222      93.0
# duckduckgo            207     220.0
# mdn                   181      23.0
# lunametrics           148     222.0
# others                147      61.0
# seroundtable          126      14.0
# edu                   110     145.0
# vk.com                100     596.0
# mysearch               96      21.0
# businessinsider        90       7.0
# yandex                 88      28.0
# outlook                85      61.0
# sogou                  73       6.0
# (not set)              69       1.0
# messenger              69      68.0
# search                 64      68.0
# metrics                57      67.0
# gophergala             46      19.0
# feedly                 41       1.0
# github                 40      22.0
# pinterest              35      73.0
# squishable             33       NaN
# arstechnica            24      12.0
# msn                    23      21.0
# linkedin               23      99.0
# mail                   23      10.0
# flipboard              23       1.0
# sm.cn                  13      10.0
# amazon                 13       5.0
# t-online.de            11      11.0
# finance.yahoo.com       6       NaN
# twitter                 5       3.0
# ad                      5       NaN
# wow                     2       1.0
